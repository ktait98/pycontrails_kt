# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import dask.array as da
import pyproj
import sys
from joblib import Parallel, delayed
from tqdm import tqdm

pd.set_option("display.max_rows", 200)
import pdb

from pycontrails import Flight, Fleet, MetDataset
from pycontrails.core import models
from pycontrails.datalib.ecmwf import ERA5
from pycontrails.physics import geo, thermo, units, constants

# from pycontrails.models.ps_model import PSFlight
# from pycontrails.models.emissions import Emissions
from pycontrails.ext.flight_gen import FlightGen
from pycontrails.models.boxmodel.boxm import Boxm

# from pycontrails.models.dry_advection import DryAdvection
from pycontrails.core.met_var import (
    AirTemperature,
    RelativeHumidity,
    SpecificHumidity,
    EastwardWind,
    NorthwardWind,
    VerticalVelocity,
)

# %%
# meteorological parameters
met_params = {
    "air_temperature": 235.0,  # K
    "specific_humidity": 0.003,  # 1
    "relative_humidity": 0.5,  # 1
    "eastward_wind": 0.0,  # m/s
    "northward_wind": 0.0,  # m/s
    "lagrangian_tendency_of_air_pressure": 0.0,  # m/s
}

# %%
# flight trajectory parameters
fl_params = {
    "t0_fl": pd.to_datetime("2022-01-20 14:00:00"),  # flight start time
    "rt_fl": pd.Timedelta(minutes=30),  # flight run time
    "ts_fl": pd.Timedelta(minutes=2),  # flight time step
    "ac_type": "A320",  # aircraft type
    "fl0_speed": 100.0,  # m/s
    "fl0_heading": 45.0,  # deg
    "fl0_coords0": (47.5, -32.5, 12500),  # lat, lon, alt [deg, deg, m]
    "sep_dist": (5000, 2000, 0),  # dx, dy, dz [m]
    "n_ac": 0,  # number of aircraft
}

# %%
# plume dispersion parameters
plume_params = {
    "dt_integration": pd.Timedelta(minutes=5),  # integration time step
    "max_age": pd.Timedelta(hours=2),  # maximum age of the plume
    "depth": 50.0,  # initial plume depth, [m]
    "width": 50.0,  # initial plume width, [m]
    "shear": 0.005,  # wind shear [1/s]
}

# %%
# chemistry sim parameters
chem_params = {
    "t0_chem": pd.to_datetime("2022-01-20 12:00:00"),  # chemistry start time
    "rt_chem": pd.Timedelta(days=30),  # chemistry runtime
    "ts_chem": pd.Timedelta(seconds=20),  # chemistry time step
    "lat_bounds": (47.0, 48.0),  # lat bounds [deg]
    "lon_bounds": (-33.0, -32.0),  # lon bounds [deg]
    "alt_bounds": (12000, 13000),  # alt bounds [m]
    "hres_chem": 0.5,  # horizontal resolution [deg]
    "vres_chem": 500,  # vertical resolution [m]
}

# %%
lats = np.arange(
    chem_params["lat_bounds"][0], chem_params["lat_bounds"][1] + chem_params["hres_chem"], chem_params["hres_chem"]
)

lons = np.arange(
    chem_params["lon_bounds"][0], chem_params["lon_bounds"][1] + chem_params["hres_chem"], chem_params["hres_chem"]
)

alts = np.arange(
    chem_params["alt_bounds"][0], chem_params["alt_bounds"][1] + chem_params["vres_chem"], chem_params["vres_chem"]
)

times = pd.date_range(
    start=chem_params["t0_chem"],
    end=chem_params["t0_chem"] + chem_params["rt_chem"],
    freq=chem_params["ts_chem"],
)

# %%
# generate artifical met dataset (boxm currently only supports zero-wind scenarios)
data_vars = {
    param: (
        ["longitude", "latitude", "level", "time"],
        da.full(
            (len(lons), len(lats), len(alts), len(times)),
            value,
            chunks=(len(lons), len(lats), len(alts), 100),
        ),
    )
    for param, value in met_params.items()
}

met = xr.Dataset(
    data_vars,
    coords={"longitude": lons, "latitude": lats, "level": units.m_to_pl(alts), "time": times},
)

met = MetDataset(met)

met
# Out:
# MetDataset with data:
#
# <xarray.Dataset> Size: 169MB
# Dimensions:                              (longitude: 3, latitude: 3, level: 3,
#                                           time: 129601)
# Coordinates:
#   * longitude                            (longitude) float64 24B -33.0 ... -32.0
#   * latitude                             (latitude) float64 24B 47.0 47.5 48.0
#   * level                                (level) float64 24B 165.1 178.6 193.3
#   * time                                 (time) datetime64[ns] 1MB 2022-01-20...
#     air_pressure                         (level) float64 24B 1.651e+04 ... 1....
#     altitude                             (level) float64 24B 1.3e+04 ... 1.2e+04
# Data variables:
#     air_temperature                      (longitude, latitude, level, time) float64 28MB dask.array<chunksize=(3, 3, 3, 100), meta=np.ndarray>
#     specific_humidity                    (longitude, latitude, level, time) float64 28MB dask.array<chunksize=(3, 3, 3, 100), meta=np.ndarray>
#     relative_humidity                    (longitude, latitude, level, time) float64 28MB dask.array<chunksize=(3, 3, 3, 100), meta=np.ndarray>
#     eastward_wind                        (longitude, latitude, level, time) float64 28MB dask.array<chunksize=(3, 3, 3, 100), meta=np.ndarray>
#     northward_wind                       (longitude, latitude, level, time) float64 28MB dask.array<chunksize=(3, 3, 3, 100), meta=np.ndarray>
#     lagrangian_tendency_of_air_pressure  (longitude, latitude, level, time) float64 28MB dask.array<chunksize=(3, 3, 3, 100), meta=np.ndarray>

# %%
# instantiate FlightGen object
fl_gen = FlightGen(met, fl_params, plume_params, chem_params)

# %%
fl = fl_gen.traj_gen()

fl
# Out:
# [Flight [4 keys x 4 length, 3 attributes]
#  	Keys: longitude, latitude, altitude, time
#  	Attributes:
#  	time                [2022-01-20 14:00:00, 2022-01-20 14:06:00]
#  	longitude           [-32.5, -32.158]
#  	latitude            [47.5, 47.728]
#  	altitude            [12500.0, 12500.0]
#  	flight_id           0
#  	aircraft_type       A320
#  	crs                 EPSG:4326]

# %%
# estimate fuel burn and emissions using ps_model and emissions model
fl = fl_gen.calc_fb_emissions()
# Out:
# /home/ktait98/pycontrails_kt/pycontrails/ext/flight_gen.py:128: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   flights[i].dataframe[column] = flights[i].dataframe[column].fillna(method='ffill')

# %%
# visualise the fleet
ax = plt.axes()
ax.set_xlim([lons[0], lons[-1]])
ax.set_ylim([lats[0], lats[-1]])
for i in fl:
    i.plot(ax=ax)

# %%
# simulate plume dispersion/advection using dry advection model
fl_df, pl_df = fl_gen.sim_plumes()

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 30)

fl_df
# Out:
# /home/ktait98/pycontrails_kt/pycontrails/ext/flight_gen.py:182: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   flights[i][column] = flights[i][column].fillna(method='ffill')
#    longitude   latitude  altitude                time  air_temperature  \
# 0 -32.500000  47.500000   12500.0 2022-01-20 14:00:00            235.0
# 1 -32.386142  47.575895   12500.0 2022-01-20 14:02:00            235.0
# 2 -32.272284  47.651791   12500.0 2022-01-20 14:04:00            235.0
# 3 -32.158426  47.727686   12500.0 2022-01-20 14:06:00            235.0
#
#    specific_humidity  true_airspeed  flight_id  aircraft_mass  \
# 0              0.003     100.098089        0.0   59354.025151
# 1              0.003     100.024704        0.0   59257.552627
# 2              0.003      99.951284        0.0   59161.077103
# 3              0.003      99.951284        0.0   59064.598579
#
#    engine_efficiency  fuel_flow  fuel_burn        thrust  rocd  \
# 0           0.097196   0.803938  96.472524  96098.682239   0.0
# 1           0.097159   0.803963  96.475524  95929.367706   0.0
# 2           0.097122   0.803988  96.478524  95796.243188   0.0
# 3           0.097122   0.803988  96.478524  95796.243188   0.0
#
#    fuel_flow_per_engine  ...   nvpm_number       CO2           H2O  \
# 0              0.401969  ...  1.051551e+17  0.000001  3.951497e-07
# 1              0.401981  ...  1.051583e+17  0.000001  3.954520e-07
# 2              0.401994  ...  1.051616e+17  0.000001  3.957547e-07
# 3              0.401994  ...  1.051616e+17  0.000001  3.957547e-07
#
#             SO2          nvPM            NO           NO2            CO  \
# 0  2.698584e-10  2.303434e-11  3.725332e-09  1.960701e-10  1.973298e-10
# 1  2.700647e-10  2.305196e-11  3.728181e-09  1.962201e-10  1.974808e-10
# 2  2.702715e-10  2.306961e-11  3.731036e-09  1.963703e-10  1.976320e-10
# 3  2.702715e-10  2.306961e-11  3.731036e-09  1.963703e-10  1.976320e-10
#
#            HCHO        CH3CHO          C2H4          C3H6          C2H2  \
# 0  2.310203e-12  7.700677e-13  2.887754e-12  7.700677e-13  7.700677e-13
# 1  2.311970e-12  7.706566e-13  2.889962e-12  7.706566e-13  7.706566e-13
# 2  2.313740e-12  7.712467e-13  2.892175e-12  7.712467e-13  7.712467e-13
# 3  2.313740e-12  7.712467e-13  2.892175e-12  7.712467e-13  7.712467e-13
#
#         BENZENE  waypoint
# 0  3.850339e-13         0
# 1  3.853283e-13         1
# 2  3.856234e-13         2
# 3  3.856234e-13         3
#
# [4 rows x 45 columns]

# %%
# fl_gen.anim_fl(fl_df, pl_df)

# %%
# convert plume dataframe to EMI geospatial xarray dataset
emi = fl_gen.plume_to_grid(lats, lons, alts, times)

# %%
# init boxm simulation and generate chemistry dataset
boxm = Boxm(met=met, params=chem_params)
# Out:
# /home/ktait98/miniconda3/envs/contrails/lib/python3.12/site-packages/xarray/backends/plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
# run boxm simulation
chem = boxm.eval(emi)
# Out:
# /home/ktait98/pycontrails_kt/pycontrails/models/boxmodel/boxm.py:167: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self.boxm_ds["ZEN_orig"] = (["time"], da.zeros((self.boxm_ds.dims["time"])))
# /home/ktait98/pycontrails_kt/pycontrails/models/boxmodel/boxm.py:169: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self.boxm_ds["J"] = (["time", "level", "longitude", "latitude", "photol_params"], da.zeros((self.boxm_ds.dims["time"], self.boxm_ds.dims["level"], self.boxm_ds.dims["longitude"], self.boxm_ds.dims["latitude"], 5)))
# /home/ktait98/pycontrails_kt/pycontrails/models/boxmodel/boxm.py:170: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self.boxm_ds["J_orig"] = (["time", "photol_params"], da.zeros((self.boxm_ds.dims["time"], 5)))
# /home/ktait98/pycontrails_kt/pycontrails/models/boxmodel/boxm.py:172: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self.boxm_ds["DJ"] = (["time", "level", "longitude", "latitude", "photol_coeffs"], da.zeros((self.boxm_ds.dims["time"], self.boxm_ds.dims["level"], self.boxm_ds.dims["longitude"], self.boxm_ds.dims["latitude"], 5)))
# /home/ktait98/pycontrails_kt/pycontrails/models/boxmodel/boxm.py:173: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self.boxm_ds["DJ_orig"] = (["time", "photol_coeffs"], da.zeros((self.boxm_ds.dims["time"], 5)))
# /home/ktait98/pycontrails_kt/pycontrails/models/boxmodel/boxm.py:175: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self.boxm_ds["RC"] = (["time", "level", "longitude", "latitude", "therm_coeffs"], da.zeros((self.boxm_ds.dims["time"], self.boxm_ds.dims["level"], self.boxm_ds.dims["longitude"], self.boxm_ds.dims["latitude"], 5)))
# /home/ktait98/pycontrails_kt/pycontrails/models/boxmodel/boxm.py:176: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self.boxm_ds["RC_orig"] = (["time", "therm_coeffs"], da.zeros((self.boxm_ds.dims["time"], 5)))
# /home/ktait98/pycontrails_kt/pycontrails/models/boxmodel/boxm.py:178: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self.boxm_ds["Y"] = (["time", "level", "longitude", "latitude", "species"], da.zeros((self.boxm_ds.dims["time"], self.boxm_ds.dims["level"], self.boxm_ds.dims["longitude"], self.boxm_ds.dims["latitude"], self.boxm_ds.dims["species"])))
# /home/ktait98/pycontrails_kt/pycontrails/models/boxmodel/boxm.py:179: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self.boxm_ds["Y_orig"] = (["time", "species"], da.zeros((self.boxm_ds.dims["time"], self.boxm_ds.dims["species"])))
# <xarray.Dataset> Size: 7GB
# Dimensions:          (time: 129601, cell: 27, species: 219, emi_species: 9,
#                       photol_params: 5, photol_coeffs: 5, therm_coeffs: 5)
# Coordinates:
#   * time             (time) datetime64[ns] 1MB 2022-01-20T12:00:00 ... 2022-0...
#     air_pressure     (cell) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
#     altitude         (cell) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
#   * species          (species) <U10 9kB 'O1D' 'O' 'OH' ... 'EMPOA' 'P2007'
#   * emi_species      (emi_species) <U7 252B 'NO' 'NO2' 'CO' ... 'C2H2' 'BENZENE'
#     level            (cell) float64 216B 165.1 165.1 165.1 ... 193.3 193.3 193.3
#     longitude        (cell) float64 216B -33.0 -33.0 -33.0 ... -32.0 -32.0 -32.0
#     latitude         (cell) float64 216B 47.0 47.5 48.0 47.0 ... 47.0 47.5 48.0
# Dimensions without coordinates: cell, photol_params, photol_coeffs, therm_coeffs
# Data variables: (12/17)
#     air_temperature  (time, cell) float64 28MB dask.array<chunksize=(129601, 27), meta=np.ndarray>
#     M                (time, cell) float64 28MB dask.array<chunksize=(129601, 27), meta=np.ndarray>
#     H2O              (time, cell) float64 28MB dask.array<chunksize=(129601, 27), meta=np.ndarray>
#     O2               (time, cell) float64 28MB dask.array<chunksize=(129601, 27), meta=np.ndarray>
#     N2               (time, cell) float64 28MB dask.array<chunksize=(129601, 27), meta=np.ndarray>
#     sza              (time, cell) float64 28MB 1.298 1.305 1.313 ... 1.164 1.17
#     ...               ...
#     DJ               (time, photol_coeffs, cell) float64 140MB dask.array<chunksize=(124275, 5, 27), meta=np.ndarray>
#     DJ_orig          (time, photol_coeffs) float64 5MB dask.array<chunksize=(129601, 5), meta=np.ndarray>
#     RC               (time, therm_coeffs, cell) float64 140MB dask.array<chunksize=(124275, 5, 27), meta=np.ndarray>
#     RC_orig          (time, therm_coeffs) float64 5MB dask.array<chunksize=(129601, 5), meta=np.ndarray>
#     Y                (time, species, cell) float64 6GB dask.array<chunksize=(2837, 219, 27), meta=np.ndarray>
#     Y_orig           (time, species) float64 227MB dask.array<chunksize=(76608, 219), meta=np.ndarray>
# Attributes:
#     dts:      20.0
# deleting boxm_ds.nc
#  TS =       122760  (Hour =    682.000000     )
#  TS =       122940  (Hour =    683.000000     )
#  TS =       123120  (Hour =    684.000000     )
#  TS =       123300  (Hour =    685.000000     )
#  TS =       123480  (Hour =    686.000000     )
#  TS =       123660  (Hour =    687.000000     )
#  TS =       123840  (Hour =    688.000000     )
#  TS =       124020  (Hour =    689.000000     )
#  TS =       124200  (Hour =    690.000000     )
#  TS =       124380  (Hour =    691.000000     )
#  TS =       124560  (Hour =    692.000000     )
#  TS =       124740  (Hour =    693.000000     )
#  TS =       124920  (Hour =    694.000000     )
#  TS =       125100  (Hour =    695.000000     )
#  TS =       125280  (Hour =    696.000000     )
#  TS =       125460  (Hour =    697.000000     )
#  TS =       125640  (Hour =    698.000000     )
#  TS =       125820  (Hour =    699.000000     )
#  TS =       126000  (Hour =    700.000000     )
#  TS =       126180  (Hour =    701.000000     )
#  TS =       126360  (Hour =    702.000000     )
#  TS =       126540  (Hour =    703.000000     )
#  TS =       126720  (Hour =    704.000000     )
#  TS =       126900  (Hour =    705.000000     )
#  TS =       127080  (Hour =    706.000000     )
#  TS =       127260  (Hour =    707.000000     )
#  TS =       127440  (Hour =    708.000000     )
#  TS =       127620  (Hour =    709.000000     )
#  TS =       127800  (Hour =    710.000000     )
#  TS =       127980  (Hour =    711.000000     )
#  TS =       128160  (Hour =    712.000000     )
#  TS =       128340  (Hour =    713.000000     )
#  TS =       128520  (Hour =    714.000000     )
#  TS =       128700  (Hour =    715.000000     )
#  TS =       128880  (Hour =    716.000000     )
#  TS =       129060  (Hour =    717.000000     )
#  TS =       129240  (Hour =    718.000000     )
#  TS =       129420  (Hour =    719.000000     )
#  TS =       129600  (Hour =    720.000000     )
# <xarray.Dataset> Size: 7GB
# Dimensions:          (time: 129601, cell: 27, species: 219, emi_species: 9,
#                       photol_params: 5, photol_coeffs: 5, therm_coeffs: 5)
# Coordinates:
#   * time             (time) datetime64[ns] 1MB 2022-01-20T12:00:00 ... 2022-0...
#     air_pressure     (cell) float64 216B ...
#     altitude         (cell) float64 216B ...
#   * species          (species) <U10 9kB 'O1D' 'O' 'OH' ... 'EMPOA' 'P2007'
#   * emi_species      (emi_species) <U7 252B 'NO' 'NO2' 'CO' ... 'C2H2' 'BENZENE'
#     level            (cell) float64 216B ...
#     longitude        (cell) float64 216B ...
#     latitude         (cell) float64 216B ...
# Dimensions without coordinates: cell, photol_params, photol_coeffs, therm_coeffs
# Data variables: (12/17)
#     air_temperature  (time, cell) float64 28MB ...
#     M                (time, cell) float64 28MB ...
#     H2O              (time, cell) float64 28MB ...
#     O2               (time, cell) float64 28MB ...
#     N2               (time, cell) float64 28MB ...
#     sza              (time, cell) float64 28MB ...
#     ...               ...
#     DJ               (time, photol_coeffs, cell) float64 140MB ...
#     DJ_orig          (time, photol_coeffs) float64 5MB ...
#     RC               (time, therm_coeffs, cell) float64 140MB ...
#     RC_orig          (time, therm_coeffs) float64 5MB ...
#     Y                (time, species, cell) float64 6GB ...
#     Y_orig           (time, species) float64 227MB ...
# Attributes:
#     dts:      20.0
# 13

# %%
# plt.figure(figsize=(10, 6))  # Optional: Adjust figure size

# print(boxm.boxm_ds["sza"].sel(cell=0).values[500])
# print(boxm.boxm_ds["ZEN_orig"].values[500])

# boxm.boxm_ds["sza"].sel(cell=0).plot()
# boxm.boxm_ds["ZEN_orig"].plot()
# plt.legend()
# plt.show()

# %%
plt.figure(figsize=(10, 6))  # Optional: Adjust figure size

#boxm.boxm_ds["Y"].sel(species="NO", cell=13).plot()
# boxm.boxm_ds["Y_orig"].sel(species="O3").plot()
# plt.legend()
# plt.show()

boxm.boxm_ds["species"].values
# Out:
# array(['O1D', 'O', 'OH', 'NO2', 'NO3', 'O3', 'N2O5', 'NO', 'HO2', 'H2',
#        'CO', 'H2O2', 'HONO', 'HNO3', 'HO2NO2', 'SO2', 'SO3', 'HSO3', 'NA',
#        'SA', 'CH4', 'CH3O2', 'C2H6', 'C2H5O2', 'C3H8', 'IC3H7O2',
#        'RN10O2', 'NC4H10', 'RN13O2', 'C2H4', 'HOCH2CH2O2', 'C3H6',
#        'RN902', 'TBUT2ENE', 'RN12O2', 'NRN6O2', 'NRN9O2', 'NRN12O2',
#        'HCHO', 'HCOOH', 'CH3CO2H', 'CH3CHO', 'C5H8', 'RU14O2', 'NRU14O2',
#        'UCARB10', 'APINENE', 'RTN28O2', 'NRTN28O2', 'RTN26O2', 'TNCARB26',
#        'RCOOH25', 'BPINENE', 'RTX28O2', 'NRTX28O2', 'RTX24O2', 'TXCARB24',
#        'TXCARB22', 'C2H2', 'CARB3', 'BENZENE', 'RA13O2', 'AROH14',
#        'TOLUENE', 'RA16O2', 'AROH17', 'OXYL', 'RA19AO2', 'RA19CO2',
#        'CH3CO3', 'C2H5CHO', 'C2H5CO3', 'CH3COCH3', 'RN8O2', 'RN11O2',
#        'CH3OH', 'C2H5OH', 'NPROPOL', 'IPROPOL', 'CH3CL', 'CH2CL2',
#        'CHCL3', 'CH3CCL3', 'TCE', 'TRICLETH', 'CDICLETH', 'TDICLETH',
#        'CARB11A', 'RN16O2', 'RN15AO2', 'RN19O2', 'RN18AO2', 'RN13AO2',
#        'RN16AO2', 'RN15O2', 'UDCARB8', 'UDCARB11', 'CARB6', 'UDCARB14',
#        'CARB9', 'MEK', 'HOCH2CHO', 'RN18O2', 'CARB13', 'CARB16',
#        'HOCH2CO3', 'RN14O2', 'RN17O2', 'UCARB12', 'RU12O2', 'CARB7',
#        'RU10O2', 'NUCARB12', 'NRU12O2', 'NOA', 'RTN25O2', 'RTN24O2',
#        'RTN23O2', 'RTN14O2', 'TNCARB10', 'RTN10O2', 'RTX22O2', 'CH3NO3',
#        'C2H5NO3', 'RN10NO3', 'IC3H7NO3', 'RN13NO3', 'RN16NO3', 'RN19NO3',
#        'HOC2H4NO3', 'RN9NO3', 'RN12NO3', 'RN15NO3', 'RN18NO3', 'RU14NO3',
#        'RA13NO3', 'RA16NO3', 'RA19NO3', 'RTN28NO3', 'RTN25NO3',
#        'RTX28NO3', 'RTX24NO3', 'RTX22NO3', 'CH3OOH', 'C2H5OOH', 'RN10OOH',
#        'IC3H7OOH', 'RN13OOH', 'RN16OOH', 'RN19OOH', 'RA13OOH', 'RA16OOH',
#        'RA19OOH', 'HOC2H4OOH', 'RN9OOH', 'RN12OOH', 'RN15OOH', 'RN18OOH',
#        'CH3CO3H', 'C2H5CO3H', 'HOCH2CO3H', 'RN8OOH', 'RN11OOH', 'RN14OOH',
#        'RN17OOH', 'RU14OOH', 'RU12OOH', 'RU10OOH', 'NRN6OOH', 'NRN9OOH',
#        'NRN12OOH', 'NRU14OOH', 'NRU12OOH', 'RTN28OOH', 'NRTN28OOH',
#        'RTN26OOH', 'RTN25OOH', 'RTN24OOH', 'RTN23OOH', 'RTN14OOH',
#        'RTN10OOH', 'RTX28OOH', 'RTX24OOH', 'RTX22OOH', 'NRTX28OOH',
#        'CARB14', 'CARB17', 'CARB10', 'CARB12', 'CARB15', 'CCARB12',
#        'ANHY', 'TNCARB15', 'RAROH14', 'ARNOH14', 'RAROH17', 'ARNOH17',
#        'PAN', 'PPN', 'PHAN', 'RU12PAN', 'MPAN', 'RTN26PAN', 'P2604',
#        'P4608', 'P2631', 'P2635', 'P4610', 'P2605', 'P2630', 'P2629',
#        'P2632', 'P2637', 'P3612', 'P3613', 'P3442', 'CH3O2NO2', 'EMPOA',
#        'P2007'], dtype='<U10')

# %%
# Resample and calculate the mean along the time dimension for each species
ds_hourly = boxm.boxm_ds["Y"].sel(cell=13).resample(time="1h").mean(dim="time")
ds_hourly_orig = boxm.boxm_ds["Y_orig"].resample(time="1h").mean(dim="time")

# Calculate the mean for each species along the time dimension
ds_hourly_mean = ds_hourly.mean(dim="time")
ds_hourly_orig_mean = ds_hourly_orig.mean(dim="time")

# Calculate the numerator and denominator for the correlation coefficient for each species
numerator = np.sum((ds_hourly - ds_hourly_mean) * (ds_hourly_orig - ds_hourly_orig_mean), axis=0)
denominator = np.sqrt(np.sum((ds_hourly - ds_hourly_mean) ** 2, axis=0) * np.sum((ds_hourly_orig - ds_hourly_orig_mean) ** 2, axis=0))

# Calculate the correlation coefficient and R² for each species
correlation_coefficient = numerator / denominator
r_squared = correlation_coefficient ** 2

# Calculate RMSE for each species
rmse = np.sqrt(np.mean((ds_hourly - ds_hourly_orig) ** 2, axis=0))

# Calculate the range of the original data for each species
range_orig = ds_hourly_orig.max(dim="time") - ds_hourly_orig.min(dim="time")

# Calculate NRMSE for each species
nrmse = rmse / range_orig * 100

# Print R² and NRMSE for each species
for s, species in enumerate(boxm.boxm_ds["species"].values):
    print(f"R² for {species} is {r_squared[s]}")
    print(f"NRMSE for {species} is {nrmse[s]}")

# Convert the r_squared and nrmse arrays to a pandas DataFrame
results_df = pd.DataFrame({
    "r_squared": r_squared,
    "nrmse": nrmse
}, index=boxm.boxm_ds["species"].values)

# Send to CSV
results_df.to_csv("/home/ktait98/pycontrails_kt/pycontrails/models/files/validation/r_squared_nrmse_NA_Airspace.csv")
# Out:
# R² for O1D is <xarray.DataArray ()> Size: 8B
# array(0.99999255)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'O1D'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for O1D is <xarray.DataArray ()> Size: 8B
# array(0.06812697)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'O1D'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for O is <xarray.DataArray ()> Size: 8B
# array(0.99999458)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'O'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for O is <xarray.DataArray ()> Size: 8B
# array(0.09649321)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'O'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for OH is <xarray.DataArray ()> Size: 8B
# array(0.99999382)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'OH'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for OH is <xarray.DataArray ()> Size: 8B
# array(0.11970742)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'OH'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NO2 is <xarray.DataArray ()> Size: 8B
# array(0.99982242)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NO2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NO2 is <xarray.DataArray ()> Size: 8B
# array(0.73390381)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NO2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NO3 is <xarray.DataArray ()> Size: 8B
# array(0.99975759)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NO3'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NO3 is <xarray.DataArray ()> Size: 8B
# array(0.87711998)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NO3'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for O3 is <xarray.DataArray ()> Size: 8B
# array(0.99999767)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'O3'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for O3 is <xarray.DataArray ()> Size: 8B
# array(0.5594539)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'O3'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for N2O5 is <xarray.DataArray ()> Size: 8B
# array(0.99990041)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'N2O5'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for N2O5 is <xarray.DataArray ()> Size: 8B
# array(0.70615168)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'N2O5'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NO is <xarray.DataArray ()> Size: 8B
# array(0.99986828)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NO'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NO is <xarray.DataArray ()> Size: 8B
# array(0.12784518)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NO'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for HO2 is <xarray.DataArray ()> Size: 8B
# array(0.99999455)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'HO2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for HO2 is <xarray.DataArray ()> Size: 8B
# array(0.10945703)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'HO2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for H2 is <xarray.DataArray ()> Size: 8B
# array(0.99999985)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'H2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for H2 is <xarray.DataArray ()> Size: 8B
# array(0.18116163)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'H2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CO is <xarray.DataArray ()> Size: 8B
# array(0.99999995)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CO'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CO is <xarray.DataArray ()> Size: 8B
# array(0.19397861)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CO'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for H2O2 is <xarray.DataArray ()> Size: 8B
# array(0.99999749)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'H2O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for H2O2 is <xarray.DataArray ()> Size: 8B
# array(0.24167337)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'H2O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for HONO is <xarray.DataArray ()> Size: 8B
# array(0.99991264)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'HONO'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for HONO is <xarray.DataArray ()> Size: 8B
# array(0.49210114)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'HONO'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for HNO3 is <xarray.DataArray ()> Size: 8B
# array(0.99999506)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'HNO3'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for HNO3 is <xarray.DataArray ()> Size: 8B
# array(0.10039056)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'HNO3'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for HO2NO2 is <xarray.DataArray ()> Size: 8B
# array(0.99987317)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'HO2NO2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for HO2NO2 is <xarray.DataArray ()> Size: 8B
# array(1.12365782)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'HO2NO2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for SO2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'SO2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for SO2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'SO2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for SO3 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'SO3'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for SO3 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'SO3'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for HSO3 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'HSO3'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for HSO3 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'HSO3'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NA is <xarray.DataArray ()> Size: 8B
# array(0.99993953)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NA'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NA is <xarray.DataArray ()> Size: 8B
# array(1.69896128)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NA'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for SA is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'SA'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for SA is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'SA'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CH4 is <xarray.DataArray ()> Size: 8B
# array(0.99999969)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CH4'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CH4 is <xarray.DataArray ()> Size: 8B
# array(0.2034851)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CH4'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CH3O2 is <xarray.DataArray ()> Size: 8B
# array(0.99998352)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CH3O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CH3O2 is <xarray.DataArray ()> Size: 8B
# array(0.22178064)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CH3O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for C2H6 is <xarray.DataArray ()> Size: 8B
# array(0.99999993)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'C2H6'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for C2H6 is <xarray.DataArray ()> Size: 8B
# array(0.20173195)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'C2H6'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for C2H5O2 is <xarray.DataArray ()> Size: 8B
# array(0.99997785)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'C2H5O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for C2H5O2 is <xarray.DataArray ()> Size: 8B
# array(0.25428118)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'C2H5O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for C3H8 is <xarray.DataArray ()> Size: 8B
# array(0.9999998)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'C3H8'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for C3H8 is <xarray.DataArray ()> Size: 8B
# array(0.18281847)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'C3H8'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for IC3H7O2 is <xarray.DataArray ()> Size: 8B
# array(0.99999487)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'IC3H7O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for IC3H7O2 is <xarray.DataArray ()> Size: 8B
# array(0.09264666)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'IC3H7O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RN10O2 is <xarray.DataArray ()> Size: 8B
# array(0.9999932)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RN10O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RN10O2 is <xarray.DataArray ()> Size: 8B
# array(0.13915691)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RN10O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NC4H10 is <xarray.DataArray ()> Size: 8B
# array(0.99999935)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NC4H10'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NC4H10 is <xarray.DataArray ()> Size: 8B
# array(0.15202063)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NC4H10'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RN13O2 is <xarray.DataArray ()> Size: 8B
# array(0.99998487)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RN13O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RN13O2 is <xarray.DataArray ()> Size: 8B
# array(0.09192362)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RN13O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for C2H4 is <xarray.DataArray ()> Size: 8B
# array(0.99999595)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'C2H4'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for C2H4 is <xarray.DataArray ()> Size: 8B
# array(0.05455303)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'C2H4'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for HOCH2CH2O2 is <xarray.DataArray ()> Size: 8B
# array(0.99992075)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'HOCH2CH2O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for HOCH2CH2O2 is <xarray.DataArray ()> Size: 8B
# array(0.12729096)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'HOCH2CH2O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for C3H6 is <xarray.DataArray ()> Size: 8B
# array(0.99999779)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'C3H6'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for C3H6 is <xarray.DataArray ()> Size: 8B
# array(0.02112093)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'C3H6'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RN902 is <xarray.DataArray ()> Size: 8B
# array(0.99998279)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RN902'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RN902 is <xarray.DataArray ()> Size: 8B
# array(0.03512199)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RN902'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for TBUT2ENE is <xarray.DataArray ()> Size: 8B
# array(0.9999971)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'TBUT2ENE'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for TBUT2ENE is <xarray.DataArray ()> Size: 8B
# array(0.01867707)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'TBUT2ENE'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RN12O2 is <xarray.DataArray ()> Size: 8B
# array(0.99995361)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RN12O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RN12O2 is <xarray.DataArray ()> Size: 8B
# array(1.12547717)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RN12O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NRN6O2 is <xarray.DataArray ()> Size: 8B
# array(0.99998074)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NRN6O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NRN6O2 is <xarray.DataArray ()> Size: 8B
# array(0.13008548)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NRN6O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NRN9O2 is <xarray.DataArray ()> Size: 8B
# array(0.99999079)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NRN9O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NRN9O2 is <xarray.DataArray ()> Size: 8B
# array(0.10882724)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NRN9O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NRN12O2 is <xarray.DataArray ()> Size: 8B
# array(0.99999573)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NRN12O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NRN12O2 is <xarray.DataArray ()> Size: 8B
# array(0.20907324)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NRN12O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for HCHO is <xarray.DataArray ()> Size: 8B
# array(0.99876404)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'HCHO'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for HCHO is <xarray.DataArray ()> Size: 8B
# array(0.69158377)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'HCHO'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for HCOOH is <xarray.DataArray ()> Size: 8B
# array(0.99999967)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'HCOOH'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for HCOOH is <xarray.DataArray ()> Size: 8B
# array(0.17211807)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'HCOOH'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CH3CO2H is <xarray.DataArray ()> Size: 8B
# array(0.99997601)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CH3CO2H'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CH3CO2H is <xarray.DataArray ()> Size: 8B
# array(0.10744227)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CH3CO2H'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CH3CHO is <xarray.DataArray ()> Size: 8B
# array(0.99998922)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CH3CHO'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CH3CHO is <xarray.DataArray ()> Size: 8B
# array(0.04538076)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CH3CHO'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for C5H8 is <xarray.DataArray ()> Size: 8B
# array(0.99999552)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'C5H8'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for C5H8 is <xarray.DataArray ()> Size: 8B
# array(0.02316051)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'C5H8'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RU14O2 is <xarray.DataArray ()> Size: 8B
# array(0.99988501)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RU14O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RU14O2 is <xarray.DataArray ()> Size: 8B
# array(0.56566391)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RU14O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NRU14O2 is <xarray.DataArray ()> Size: 8B
# array(0.99999423)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NRU14O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NRU14O2 is <xarray.DataArray ()> Size: 8B
# array(0.19513933)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NRU14O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for UCARB10 is <xarray.DataArray ()> Size: 8B
# array(0.99998984)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'UCARB10'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for UCARB10 is <xarray.DataArray ()> Size: 8B
# array(2.5113762)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'UCARB10'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for APINENE is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'APINENE'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for APINENE is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'APINENE'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RTN28O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RTN28O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RTN28O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RTN28O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NRTN28O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NRTN28O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NRTN28O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NRTN28O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RTN26O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RTN26O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RTN26O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RTN26O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for TNCARB26 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'TNCARB26'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for TNCARB26 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'TNCARB26'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RCOOH25 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RCOOH25'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RCOOH25 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RCOOH25'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for BPINENE is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'BPINENE'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for BPINENE is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'BPINENE'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RTX28O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RTX28O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RTX28O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RTX28O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NRTX28O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NRTX28O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NRTX28O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NRTX28O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RTX24O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RTX24O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RTX24O2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RTX24O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for TXCARB24 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'TXCARB24'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for TXCARB24 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'TXCARB24'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for TXCARB22 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'TXCARB22'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for TXCARB22 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'TXCARB22'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for C2H2 is <xarray.DataArray ()> Size: 8B
# array(0.99999986)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'C2H2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for C2H2 is <xarray.DataArray ()> Size: 8B
# array(0.19026678)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'C2H2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CARB3 is <xarray.DataArray ()> Size: 8B
# array(0.99999793)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CARB3'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CARB3 is <xarray.DataArray ()> Size: 8B
# array(0.10388764)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CARB3'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for BENZENE is <xarray.DataArray ()> Size: 8B
# array(0.99999967)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'BENZENE'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for BENZENE is <xarray.DataArray ()> Size: 8B
# array(0.17150765)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'BENZENE'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RA13O2 is <xarray.DataArray ()> Size: 8B
# array(0.9999924)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RA13O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RA13O2 is <xarray.DataArray ()> Size: 8B
# array(0.07697739)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RA13O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for AROH14 is <xarray.DataArray ()> Size: 8B
# array(0.9998837)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'AROH14'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for AROH14 is <xarray.DataArray ()> Size: 8B
# array(0.36457295)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'AROH14'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for TOLUENE is <xarray.DataArray ()> Size: 8B
# array(0.99999638)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'TOLUENE'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for TOLUENE is <xarray.DataArray ()> Size: 8B
# array(0.07265428)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'TOLUENE'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RA16O2 is <xarray.DataArray ()> Size: 8B
# array(0.99998748)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RA16O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RA16O2 is <xarray.DataArray ()> Size: 8B
# array(0.04460724)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RA16O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for AROH17 is <xarray.DataArray ()> Size: 8B
# array(0.9999769)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'AROH17'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for AROH17 is <xarray.DataArray ()> Size: 8B
# array(0.22397854)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'AROH17'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for OXYL is <xarray.DataArray ()> Size: 8B
# array(0.99999563)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'OXYL'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for OXYL is <xarray.DataArray ()> Size: 8B
# array(0.04587015)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'OXYL'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RA19AO2 is <xarray.DataArray ()> Size: 8B
# array(0.99998749)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RA19AO2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RA19AO2 is <xarray.DataArray ()> Size: 8B
# array(0.03567667)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RA19AO2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RA19CO2 is <xarray.DataArray ()> Size: 8B
# array(0.99998749)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RA19CO2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RA19CO2 is <xarray.DataArray ()> Size: 8B
# array(0.03567666)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RA19CO2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CH3CO3 is <xarray.DataArray ()> Size: 8B
# array(0.99999152)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CH3CO3'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CH3CO3 is <xarray.DataArray ()> Size: 8B
# array(0.13296419)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CH3CO3'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for C2H5CHO is <xarray.DataArray ()> Size: 8B
# array(0.99983063)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'C2H5CHO'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for C2H5CHO is <xarray.DataArray ()> Size: 8B
# array(0.18001054)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'C2H5CHO'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for C2H5CO3 is <xarray.DataArray ()> Size: 8B
# array(0.99999433)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'C2H5CO3'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for C2H5CO3 is <xarray.DataArray ()> Size: 8B
# array(0.18152995)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'C2H5CO3'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CH3COCH3 is <xarray.DataArray ()> Size: 8B
# array(0.99996958)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CH3COCH3'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CH3COCH3 is <xarray.DataArray ()> Size: 8B
# array(0.44281131)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CH3COCH3'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RN8O2 is <xarray.DataArray ()> Size: 8B
# array(0.9999973)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RN8O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RN8O2 is <xarray.DataArray ()> Size: 8B
# array(0.09313956)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RN8O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RN11O2 is <xarray.DataArray ()> Size: 8B
# array(0.99999691)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RN11O2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RN11O2 is <xarray.DataArray ()> Size: 8B
# array(0.08288919)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RN11O2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CH3OH is <xarray.DataArray ()> Size: 8B
# array(0.9996319)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CH3OH'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CH3OH is <xarray.DataArray ()> Size: 8B
# array(1.52848032)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CH3OH'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for C2H5OH is <xarray.DataArray ()> Size: 8B
# array(0.9999986)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'C2H5OH'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for C2H5OH is <xarray.DataArray ()> Size: 8B
# array(0.65078204)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'C2H5OH'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for NPROPOL is <xarray.DataArray ()> Size: 8B
# array(0.9999985)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'NPROPOL'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for NPROPOL is <xarray.DataArray ()> Size: 8B
# array(0.67218551)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'NPROPOL'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for IPROPOL is <xarray.DataArray ()> Size: 8B
# array(0.99999833)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'IPROPOL'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for IPROPOL is <xarray.DataArray ()> Size: 8B
# array(0.6625774)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'IPROPOL'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CH3CL is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CH3CL'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CH3CL is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CH3CL'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CH2CL2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CH2CL2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CH2CL2 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CH2CL2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CHCL3 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CHCL3'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CHCL3 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CHCL3'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CH3CCL3 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CH3CCL3'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CH3CCL3 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CH3CCL3'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for TCE is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'TCE'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for TCE is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
# ...
#     latitude      float64 8B ...
# R² for ANHY is <xarray.DataArray ()> Size: 8B
# array(0.99990124)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'ANHY'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for ANHY is <xarray.DataArray ()> Size: 8B
# array(2.95602643)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'ANHY'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for TNCARB15 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'TNCARB15'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for TNCARB15 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'TNCARB15'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RAROH14 is <xarray.DataArray ()> Size: 8B
# array(0.99937908)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RAROH14'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RAROH14 is <xarray.DataArray ()> Size: 8B
# array(1.52718342)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RAROH14'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for ARNOH14 is <xarray.DataArray ()> Size: 8B
# array(0.99994072)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'ARNOH14'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for ARNOH14 is <xarray.DataArray ()> Size: 8B
# array(3.6861574)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'ARNOH14'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RAROH17 is <xarray.DataArray ()> Size: 8B
# array(0.99974445)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RAROH17'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RAROH17 is <xarray.DataArray ()> Size: 8B
# array(0.69911153)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RAROH17'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for ARNOH17 is <xarray.DataArray ()> Size: 8B
# array(0.99849197)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'ARNOH17'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for ARNOH17 is <xarray.DataArray ()> Size: 8B
# array(3.71991224)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'ARNOH17'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for PAN is <xarray.DataArray ()> Size: 8B
# array(0.99994666)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'PAN'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for PAN is <xarray.DataArray ()> Size: 8B
# array(1.62446355)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'PAN'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for PPN is <xarray.DataArray ()> Size: 8B
# array(0.99992319)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'PPN'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for PPN is <xarray.DataArray ()> Size: 8B
# array(1.52829941)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'PPN'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for PHAN is <xarray.DataArray ()> Size: 8B
# array(0.99999553)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'PHAN'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for PHAN is <xarray.DataArray ()> Size: 8B
# array(0.79436779)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'PHAN'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RU12PAN is <xarray.DataArray ()> Size: 8B
# array(0.99754458)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RU12PAN'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RU12PAN is <xarray.DataArray ()> Size: 8B
# array(1.56501658)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RU12PAN'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for MPAN is <xarray.DataArray ()> Size: 8B
# array(0.99999676)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'MPAN'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for MPAN is <xarray.DataArray ()> Size: 8B
# array(0.0827876)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'MPAN'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for RTN26PAN is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'RTN26PAN'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for RTN26PAN is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'RTN26PAN'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P2604 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P2604'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P2604 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P2604'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P4608 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P4608'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P4608 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P4608'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P2631 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P2631'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P2631 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P2631'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P2635 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P2635'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P2635 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P2635'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P4610 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P4610'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P4610 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P4610'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P2605 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P2605'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P2605 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P2605'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P2630 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P2630'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P2630 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P2630'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P2629 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P2629'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P2629 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P2629'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P2632 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P2632'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P2632 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P2632'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P2637 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P2637'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P2637 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P2637'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P3612 is <xarray.DataArray ()> Size: 8B
# array(0.99994076)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P3612'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P3612 is <xarray.DataArray ()> Size: 8B
# array(3.68993135)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P3612'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P3613 is <xarray.DataArray ()> Size: 8B
# array(0.99849681)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P3613'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P3613 is <xarray.DataArray ()> Size: 8B
# array(3.72497187)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P3613'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P3442 is <xarray.DataArray ()> Size: 8B
# array(0.99990155)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P3442'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P3442 is <xarray.DataArray ()> Size: 8B
# array(2.96014203)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P3442'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for CH3O2NO2 is <xarray.DataArray ()> Size: 8B
# array(0.99984398)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'CH3O2NO2'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for CH3O2NO2 is <xarray.DataArray ()> Size: 8B
# array(1.07048236)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'CH3O2NO2'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for EMPOA is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'EMPOA'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for EMPOA is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'EMPOA'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...
# R² for P2007 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#     species       <U10 40B 'P2007'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5
# NRMSE for P2007 is <xarray.DataArray ()> Size: 8B
# array(nan)
# Coordinates:
#     air_pressure  float64 8B ...
#     altitude      float64 8B ...
#     species       <U10 40B 'P2007'
#     level         float64 8B ...
#     longitude     float64 8B ...
#     latitude      float64 8B ...

# %%
# correlation_coefficient = (np.sum((ds_hourly - ds_hourly.mean()) * (ds_hourly_orig - ds_hourly_orig.mean()))) / \
#                           np.sqrt(np.sum((ds_hourly - ds_hourly.mean()) ** 2) * np.sum((ds_hourly_orig - ds_hourly_orig.mean()) ** 2))
# r_squared = correlation_coefficient ** 2

r_squared
# Out:
# <xarray.DataArray (species: 219)> Size: 2kB
# array([0.99999255, 0.99999458, 0.99999382, 0.99982242, 0.99975759,
#        0.99999767, 0.99990041, 0.99986828, 0.99999455, 0.99999985,
#        0.99999995, 0.99999749, 0.99991264, 0.99999506, 0.99987317,
#               nan,        nan,        nan, 0.99993953,        nan,
#        0.99999969, 0.99998352, 0.99999993, 0.99997785, 0.9999998 ,
#        0.99999487, 0.9999932 , 0.99999935, 0.99998487, 0.99999595,
#        0.99992075, 0.99999779, 0.99998279, 0.9999971 , 0.99995361,
#        0.99998074, 0.99999079, 0.99999573, 0.99876404, 0.99999967,
#        0.99997601, 0.99998922, 0.99999552, 0.99988501, 0.99999423,
#        0.99998984,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan, 0.99999986, 0.99999793,
#        0.99999967, 0.9999924 , 0.9998837 , 0.99999638, 0.99998748,
#        0.9999769 , 0.99999563, 0.99998749, 0.99998749, 0.99999152,
#        0.99983063, 0.99999433, 0.99996958, 0.9999973 , 0.99999691,
#        0.9996319 , 0.9999986 , 0.9999985 , 0.99999833,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan, 0.99999387, 0.99989012, 0.9999218 ,
#               nan,        nan,        nan,        nan, 0.99995868,
#        0.99996654, 0.99999491, 0.999993  , 0.99996799, 0.99999145,
# ...
#               nan,        nan, 0.99993682, 0.9999346 , 0.99986966,
#        0.99982244, 0.99981373, 0.99988475,        nan, 0.99998766,
#        0.99995836, 0.9999555 , 0.99982481,        nan, 0.99999287,
#        0.99995043, 0.99997332, 0.99998197,        nan,        nan,
#               nan,        nan,        nan, 0.999982  , 0.99999938,
#        0.99999888, 0.99999929, 0.99999046, 0.99969037,        nan,
#        0.99999362, 0.99999362, 0.99999002, 0.99996292, 0.99996576,
#        0.99992571, 0.99981326,        nan, 0.99999921, 0.99999783,
#        0.99969495, 0.99999936, 0.99999825, 0.99988078,        nan,
#        0.99995945, 0.9959814 , 0.99994011, 0.99998603, 0.99999791,
#        0.99999559, 0.99999178, 0.99976992,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#        0.99983776,        nan, 0.99998528, 0.99991279,        nan,
#               nan, 0.99990124,        nan, 0.99937908, 0.99994072,
#        0.99974445, 0.99849197, 0.99994666, 0.99992319, 0.99999553,
#        0.99754458, 0.99999676,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan, 0.99994076, 0.99849681,
#        0.99990155, 0.99984398,        nan,        nan])
# Coordinates:
#     air_pressure  float64 8B 1.786e+04
#     altitude      float64 8B 1.25e+04
#   * species       (species) <U10 9kB 'O1D' 'O' 'OH' ... 'EMPOA' 'P2007'
#     level         float64 8B 178.6
#     longitude     float64 8B -32.5
#     latitude      float64 8B 47.5

# %%
boxm.boxm_ds["Y"].sel(species="NO3").isel(time=1000).plot()

# %%
#boxm.anim_chem("Y_perc_diff", "O3", 410.6)

# %%
boxm.params
# Out:
# {'copy_source': True,
#  'interpolation_method': 'linear',
#  'interpolation_bounds_error': False,
#  'interpolation_fill_value': nan,
#  'interpolation_localize': False,
#  'interpolation_use_indices': False,
#  'interpolation_q_method': None,
#  'verify_met': True,
#  'downselect_met': True,
#  'met_longitude_buffer': (0.0, 0.0),
#  'met_latitude_buffer': (0.0, 0.0),
#  'met_level_buffer': (0.0, 0.0),
#  'met_time_buffer': (numpy.timedelta64(0,'h'), numpy.timedelta64(0,'h')),
#  'lat_bounds': (47.0, 48.0),
#  'lon_bounds': (-33.0, -32.0),
#  'alt_bounds': (12000, 13000),
#  'hres_chem': 0.5,
#  'vres_chem': 500,
#  't0_chem': Timestamp('2022-01-20 12:00:00'),
#  'rt_chem': Timedelta('30 days 00:00:00'),
#  'ts_chem': Timedelta('0 days 00:00:20')}

# %%
# fig, axs = plt.subplots(3, 3, sharex=True, figsize=(15, 12), constrained_layout=True)
# fig.suptitle('Box model validation - North Atlantic Airspace')

# axs[0, 0].plot(boxm.boxm_ds["Y"].sel(species="NO", cell=13).values, 'r.-', lw=0.2)
# axs[0, 0].plot(boxm.boxm_ds["Y_orig"].sel(species="NO").values, 'b.-', lw=0.2)
# axs[0, 0].set(title='NO', xlabel='time [s]', ylabel='concentration [ppb]')

# axs[0, 1].plot(boxm.boxm_ds["Y"].sel(species="NO2", cell=13).values, 'r.-', lw=0.2)
# axs[0, 1].plot(boxm.boxm_ds["Y_orig"].sel(species="NO2").values, 'b.-', lw=0.2)
# axs[0, 1].set(title='NO2', xlabel='time [s]', ylabel='concentration [ppb]')

# axs[0, 2].plot(boxm.boxm_ds["Y"].sel(species="OH", cell=13).values, 'r.-', lw=0.2)
# axs[0, 2].plot(boxm.boxm_ds["Y_orig"].sel(species="OH").values, 'b.-', lw=0.2)
# axs[0, 2].set(title='OH', xlabel='time [s]', ylabel='concentration [ppb]')

# axs[1, 0].plot(boxm.boxm_ds["Y"].sel(species="HO2", cell=13).values, 'r.-', lw=0.2)
# axs[1, 0].plot(boxm.boxm_ds["Y_orig"].sel(species="HO2").values, 'b.-', lw=0.2)
# axs[1, 0].set(title='HO2', xlabel='time [s]', ylabel='concentration [ppb]')

# axs[1, 1].plot(boxm.boxm_ds["Y"].sel(species="O3", cell=13).values, 'r.-', lw=0.2)
# axs[1, 1].plot(boxm.boxm_ds["Y_orig"].sel(species="O3").values, 'b.-', lw=0.2)
# axs[1, 1].set(title='O3', xlabel='time [s]', ylabel='concentration [ppb]')

# axs[1, 2].plot(boxm.boxm_ds["Y"].sel(species="CO", cell=13).values, 'r.-', lw=0.2)
# axs[1, 2].plot(boxm.boxm_ds["Y_orig"].sel(species="CO").values, 'b.-', lw=0.2)
# axs[1, 2].set(title='CO', xlabel='time [s]', ylabel='concentration [ppb]')

# axs[2, 0].plot(boxm.boxm_ds["Y"].sel(species="CH4", cell=13).values, 'r.-', lw=0.2)
# axs[2, 0].plot(boxm.boxm_ds["Y_orig"].sel(species="CH4").values, 'b.-', lw=0.2)
# axs[2, 0].set(title='CH4', xlabel='time [s]', ylabel='concentration [ppb]')

# axs[2, 1].plot(boxm.boxm_ds["Y"].sel(species="HCHO", cell=13).values, 'r.-', lw=0.2)
# axs[2, 1].plot(boxm.boxm_ds["Y_orig"].sel(species="HCHO").values, 'b.-', lw=0.2)
# axs[2, 1].set(title='HCHO', xlabel='time [s]', ylabel='concentration [ppb]')

# axs[2, 2].plot(boxm.boxm_ds["Y"].sel(species="HONO", cell=13).values, 'r.-', lw=0.2)
# axs[2, 2].plot(boxm.boxm_ds["Y_orig"].sel(species="HONO").values, 'b.-', lw=0.2)
# axs[2, 2].set(title='HONO', xlabel='time [s]', ylabel='concentration [ppb]')

# plt.savefig('/home/ktait98/pycontrails_kt/pycontrails/models/files/validation/NA_Airspace.png', dpi=1000)
